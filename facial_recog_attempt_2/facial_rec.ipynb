# %%
import os
import random
import numpy as np
from matplotlib import pyplot as plt

import tensorflow as tf
from keras.models import Model
from keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
from face_tracking import data_collection
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 9
#       7 from keras.models import Model
#       8 from keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
# ----> 9 from face_tracking import data_collection
#
# File ~/Desktop/Cal Poly/CSC 487/csc487_project/face_tracking.py:5
#       3 import os
#       4 import time
# ----> 5 from helpers import display_progressbar
#       7 TIMESTEP_FOR_IMAGE_DOWNLOAD = 0
#       8 MODEL_INPUT_IMAGE_DIMENSIONS = (250, 250)
#
# File ~/Desktop/Cal Poly/CSC 487/csc487_project/helpers.py:8
#       6 from keras.applications import vgg19
#       7 import os
# ----> 8 import albumentations as alb
#       9 import cv2
#      10 from PIL import Image
#
# ModuleNotFoundError: No module named 'albumentations'

# %%
POS_PATH = os.path.join('data', 'positive')
NEG_PATH = os.path.join('data', 'negative')
ANC_PATH = os.path.join('data', 'anchor')

# %%
import uuid
import cv2

cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Failed to caputre frame")
        break
    frame = frame[240:240+250, 500:500+250, :]
    cv2.imshow('Image Collection', frame)

    k = cv2.waitKey(1)
    if k % 256 == 27:
        print("Escape key hit, closing")
        break
    if k & 0xFF == ord('a'):
        print("Anchor pic taken")
        img_name = os.path.join(ANC_PATH, f'{uuid.uuid1()}.jpg')
        cv2.imwrite(img_name, frame)
    if k & 0xFF == ord('p'):
        print("Positive pic taken")
        img_name = os.path.join(POS_PATH, f'{uuid.uuid1()}.jpg')
        cv2.imwrite(img_name, frame)


cap.release()
cv2.destroyWindow('Image Collection')
print("Done!")

data_collection
# Out:
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Positive pic taken
# Escape key hit, closing
# Done!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 31
#      28 cv2.destroyWindow('Image Collection')
#      29 print("Done!")
# ---> 31 data_collection
#
# NameError: name 'data_collection' is not defined
